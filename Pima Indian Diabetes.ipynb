# %% [markdown]
# # PRANSHU SHARMA
#
#
# ## Pima Indians Diabetes Dataset
#
# ### Content
# The datasets consists of several medical predictor variables and one target variable, Outcome. Predictor variables includes the number of pregnancies the patient has had, their BMI, insulin level, age, and so on
#
# ### Data Dictionary
# Pregnancies-
# Number of times pregnant
#
# Glucose-
# Plasma glucose concentration a 2 hours in an oral glucose tolerance test
#
# BloodPressure-
# Diastolic blood pressure (mm Hg)
#
# SkinThickness-
# Triceps skin fold thickness (mm)
#
# Insulin-
# 2-Hour serum insulin (mu U/ml)
#
# BMI-
# Body mass index (weight in kg/(height in m)^2)
#
# DiabetesPedigreeFunction-
# Diabetes pedigree function
#
# Age-
# Age (years)
#
# Outcome-
# Class variable (0 or 1) 268 of 768 are 1, the others are 0
#
# ## Task
# Performing Exploratory Data Analysis on the dataset
# Data Cleaning
# Data Modelling

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
sns.set()

# %% [markdown]
# # Loading Dataset

# %%
data = pd.read_csv('diabetes.csv')
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# # Checking about Null Entries

# %%
data.isnull().sum().any()
# Out:
# False

# %% [markdown]
# # Checking Unique values in every feature columns

# %%
print('unique values\n')
for i in data.columns:
     print(i,len(data[i].unique()))
# Out:
# unique values
#
# Pregnancies 17
# Glucose 136
# BloodPressure 47
# SkinThickness 51
# Insulin 186
# BMI 248
# DiabetesPedigreeFunction 517
# Age 52
# Outcome 2

# %% [markdown]
# #### outcome is categorical feature, other features are numerical in nature , therefore dropping outcome from data

# %%
new_data = data.copy()
new_data.drop(['Outcome'],axis=1,inplace=True)

# %% [markdown]
# # Visualization of Numerical Features

# %%
new_data.hist(figsize=(12,10))
plt.show()

# %% [markdown]
# #### From above distribution we can see there are so many outliers like in case of BMI, Blood Pressure , Glucose , Insulin ,Skin Thickness and so on

# %%
for i in new_data.columns:
    sns.boxplot(x=new_data[i])
    plt.title(i)
    plt.show()

# %% [markdown]
# #### Data Insights
# 1 Variable: Age
#   Maximum people lies in range of — 21.0 to 40.0.
#   Min value is 21.0.
#   Mean is 33.24.
#
# 2 Variable: Blood Pressure(BP)
#
# Maximum people in range of —  65 to 100.
# Min value is 0, which is not possible as in real world.
#
# 3 Variable: Body Mass Index (BMI)
#
# Maximum people lies in range of — 20 to 40.
# Min value is 0 in BMI, which is not possible as in real world.
#
# 4 Variable: Diabetes Pedigree Function (DPF)
#
#
# Maximum people lies in range of — 0.08 to 0.5.
# Min value is 0.08.
# Mean is 0.47
#
# 5 Variable: Glucose
#
# Maximum people lies in range of — 100 to 140.
#
# Min value is 0, which is not possible as in real world.
#
# 6 Variable: Insulin
#
#
# Maximum people lies in range of — 0 to 400.
# Standard deviation is 115.4, which says there are less people with high Insulin.
#
# 7 Variable: Pregnancies
#
#
# Histogram & Boxplot for Pregnancies
#
# Maximum people lies in range of — 0 to 5.
# Mean — 3.85.
# Max — 17.0
#
#
# 8 Variable: Skin Thickness
#
# Mean — 20.54
# Min value is 0, which is not possible as in real world.
# Max value is 99.

# %% [markdown]
# # Visualization Of Categorical Feature

# %%
data['Outcome'].value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %% [markdown]
#  #### 0 means not having diabetes , 1 means having Diabetes

# %%
plt.figure(figsize=(7, 5))
sns.countplot(x=data['Outcome'])
plt.show()

# %% [markdown]
# # Checking Correlation between variables

# %%
sns.heatmap(new_data.corr(),annot = True)

# %% [markdown]
# #### Data Insights
# There's Not much Correlation between variables
# * Age and Pregnancy are moderately correlated which can tell roughly as no of pregnancies will be be more in case of elder Female in contrast to younger ones
# * Glucose and outcome( of diabetes) are also a showing a bit of co rrelation

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Removing Outliers

# %% [markdown]
# ### For Checking the 'Pregnancies' column

# %%
new_data['Pregnancies'].value_counts()
# Out:
# 1     135
# 0     111
# 2     103
# 3      75
# 4      68
# 5      57
# 6      50
# 7      45
# 8      38
# 9      28
# 10     24
# 11     11
# 13     10
# 12      9
# 14      2
# 15      1
# 17      1
# Name: Pregnancies, dtype: int64

# %%
sns.distplot(new_data['Pregnancies'], bins=10)
plt.title('Histogram')
plt.show()

# %%
stats.probplot(new_data['Pregnancies'], dist='norm', fit=True, plot=plt)
plt.title('Q-Q Plot')
# Out:
# Text(0.5, 1.0, 'Q-Q Plot')

# %%
# taking 95% percentile
max_threshold = new_data['Pregnancies'].quantile(0.95)
new_data = new_data[new_data['Pregnancies']<=max_threshold]

# %% [markdown]
# ### Checking the 'Glucose' column

# %%
sns.distplot(new_data['Glucose'], bins=10)
plt.title('Histogram')
plt.show()

# %%
 stats.probplot(new_data['Glucose'], dist='norm', fit=True, plot=plt)
plt.title('Q-Q Plot')
# Out:
# Text(0.5, 1.0, 'Q-Q Plot')

# %%
new_data = new_data[new_data['Glucose']>=25]   # removal of outliers as can be seen from above graphs

# %% [markdown]
# ### Checking the 'BloodPressure' column -

# %%
sns.distplot(new_data['BloodPressure'], bins=10)
plt.title('Histogram')
plt.show()

# %%
 stats.probplot(new_data['BloodPressure'], dist='norm', fit=True, plot=plt)
plt.title('Q-Q Plot')
# Out:
# Text(0.5, 1.0, 'Q-Q Plot')

# %%
new_data = new_data[new_data['BloodPressure']!=0]   # removal of outliers as can be seen from above graphs

# %% [markdown]
# ### Checking the 'BMI' column -

# %%
sns.distplot(new_data['BMI'], bins=10)
plt.title('Histogram')
plt.show()

# %%
stats.probplot(new_data['BMI'], dist='norm', fit=True, plot=plt)
plt.title('Q-Q Plot')
# Out:
# Text(0.5, 1.0, 'Q-Q Plot')

# %%
new_data = new_data[(new_data['BMI']>10) & (new_data['BMI']<50)]   # removal of outliers as can be seen from above graphs

# %% [markdown]
# ### Checking the 'Insulin' column -

# %%
sns.distplot(new_data['Insulin'], bins=10)
plt.title('Histogram')
plt.show()

# %%
stats.probplot(new_data['Insulin'], dist='norm', fit=True, plot=plt)
plt.title('Q-Q Plot')
# Out:
# Text(0.5, 1.0, 'Q-Q Plot')

# %%
# we should check columns
new_data['Insulin'].value_counts().sort_index(ascending=False)
# Out:
# 846      1
# 744      1
# 600      1
# 579      1
# 545      1
#       ...
# 22       1
# 18       2
# 16       1
# 15       1
# 0      314
# Name: Insulin, Length: 177, dtype: int64

# %%
new_data = new_data[new_data['Insulin'].between(15, 600)] # removing outliers

# %% [markdown]
# ### Checking the 'SkinThickness' column

# %%
sns.distplot(new_data['SkinThickness'], bins=10)
plt.title('Histogram')
plt.show()

# %%
stats.probplot(new_data['SkinThickness'], dist='norm', fit=True, plot=plt)
plt.title('Q-Q Plot')
# Out:
# Text(0.5, 1.0, 'Q-Q Plot')

# %%
new_data = new_data[(new_data['BMI']<60)] # removing outliers

# %% [markdown]
# ### Checking the 'DiabetesPedigreeFunction' column -

# %%
sns.distplot(new_data['DiabetesPedigreeFunction'], bins=10)
plt.title('Histogram')
plt.show()

# %%
stats.probplot(new_data['DiabetesPedigreeFunction'], dist='norm', fit=True, plot=plt)
plt.title('Q-Q Plot')
# Out:
# Text(0.5, 1.0, 'Q-Q Plot')

# %%
new_data = new_data[(new_data['DiabetesPedigreeFunction']<1.5)] # removing outliers

# %%
new_data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 3              1       89             66             23       94  28.1
# 6              3       78             50             32       88  31.0
# 8              2      197             70             45      543  30.5
# 14             5      166             72             19      175  25.8
# 16             0      118             84             47      230  45.8
# ..           ...      ...            ...            ...      ...   ...
# 753            0      181             88             44      510  43.3
# 755            1      128             88             39      110  36.5
# 760            2       88             58             26       16  28.4
# 763           10      101             76             48      180  32.9
# 765            5      121             72             23      112  26.2
#
#      DiabetesPedigreeFunction  Age
# 3                       0.167   21
# 6                       0.248   26
# ...

# %%
new_data.shape
# Out:
# (364, 8)
